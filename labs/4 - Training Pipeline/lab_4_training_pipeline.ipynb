# %% [markdown]
# # Lab 4 - Training Pipeline
#
# Goal: run model training from Python code instead of doing everything manually in a notebook.

# %% [markdown]
# ## Files to inspect
#
# - `src/training/preprocess.py`
# - `src/training/train.py`
# - `config/config.yml`

# %%
from src.training.preprocess import load_data, wrangle
from src.training.train import split_features_target

df = wrangle(load_data())
X, y = split_features_target(df)

print("Features shape:", X.shape)
print("Target shape:", y.shape)
print(y.value_counts(normalize=True))

# %%
# Run this from a terminal:
# docker compose up -d mlflow
# python -m src.training.train
