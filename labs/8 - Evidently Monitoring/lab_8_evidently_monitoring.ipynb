# %% [markdown]
# # Lab 8 - Evidently Monitoring
#
# Goal: compare reference training data with current ingested data and generate a drift report.

# %% [markdown]
# ## Files to inspect
#
# - `src/monitoring/drift.py`
# - `requirements/monitoring.txt`

# %%
from src.monitoring.drift import FEATURE_COLUMNS, NUMERICAL_COLUMNS, CATEGORICAL_COLUMNS

print("Feature columns:", FEATURE_COLUMNS)
print("Numerical columns:", NUMERICAL_COLUMNS)
print("Categorical columns:", CATEGORICAL_COLUMNS)

# %%
# Run this from a terminal:
# python -m src.monitoring.drift

# Output:
# reports/drift_report.html
