# %% [markdown]
# # Lab 5 - Model Registry
#
# Goal: register the best MLflow model only if it passes the configured threshold.

# %% [markdown]
# ## Files to inspect
#
# - `src/training/registry.py`
# - `src/training/train.py`
# - `config/config.yml`

# %%
from config.config import CONFIG

print("Model name:", CONFIG["mlflow"]["model_name"])
print("Experiment:", CONFIG["mlflow"]["experiment_name"])
print("Minimum F1 score:", CONFIG["train"]["min_f1_score"])

# %%
# Run this from a terminal:
# python -m src.training.train

# Then check the MLflow UI:
# http://127.0.0.1:5123
