# %% [markdown]
# # Lab 9 - Prefect, Docker, and CI
#
# Goal: run the project as simple workflows and Docker services.

# %% [markdown]
# ## Files to inspect
#
# - `src/orchestration/flows.py`
# - `Dockerfile`
# - `docker-compose.yml`
# - `.github/workflows/ci.yml`

# %%
# Run orchestration locally from a terminal:
# python -m src.orchestration.flows

# Run the main Docker stack:
# docker compose up --build

# Run one-off jobs:
# docker compose --profile jobs run --rm training
# docker compose --profile jobs run --rm monitoring
# docker compose --profile jobs run --rm orchestration
